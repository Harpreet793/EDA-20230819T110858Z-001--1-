# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('IPL2013.csv')

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.head().transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df['PLAYER NAME'][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
df[['PLAYER NAME','COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
df.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
df['COUNTRY'].value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
df['COUNTRY'].value_counts(normalize = True)*100
# Out:
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: COUNTRY, dtype: float64

# %% [markdown]
# ## cross-tabulation

# %%
pd.crosstab(df['AGE'],df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %% [markdown]
# ## Sorting

# %%
df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE',ascending = False)[0:10]
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000
# 83   Pietersen, KP     1550000
# 23     Flintoff, A     1550000
# 15       Dhoni, MS     1500000
# 108     Symonds, A     1350000
# 110   Taylor, LRPL     1000000

# %% [markdown]
# ### Need to create column Premium. Premium = Sold price - Base Price

# %%
df['PREMIUM'] = df['SOLD PRICE']-df['BASE PRICE']

# %%
df[['PLAYER NAME','COUNTRY','SOLD PRICE','BASE PRICE','PREMIUM']][0:5]
# Out:
#     PLAYER NAME COUNTRY  SOLD PRICE  BASE PRICE  PREMIUM
# 0   Abdulla, YA      SA       50000       50000        0
# 1  Abdur Razzak     BAN       50000       50000        0
# 2   Agarkar, AB     IND      350000      200000   150000
# 3     Ashwin, R     IND      850000      100000   750000
# 4  Badrinath, S     IND      800000      100000   700000

# %%
df[['PLAYER NAME','COUNTRY','SOLD PRICE','BASE PRICE','PREMIUM']].sort_values('PREMIUM',ascending = False)[0:5]
# Out:
#        PLAYER NAME COUNTRY  SOLD PRICE  BASE PRICE  PREMIUM
# 50        Kohli, V     IND     1800000      150000  1650000
# 113     Tiwary, SS     IND     1600000      100000  1500000
# 127   Yuvraj Singh     IND     1800000      400000  1400000
# 111  Tendulkar, SR     IND     1800000      400000  1400000
# 93       Sehwag, V     IND     1800000      400000  1400000

# %% [markdown]
# ## Grouping and Aggregation

# %%
df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
df.groupby('AGE')['SOLD PRICE'].sum()
# Out:
# AGE
# 1    11524000
# 2    41670000
# 3    14565000
# Name: SOLD PRICE, dtype: int64

# %% [markdown]
# ## Filtering Records basesd on condition

# %% [markdown]
# condition is no of sixers must be greater than 80

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE', 'PREMIUM'],
#       dtype='object')

# %%
df[df['SIXERS']>80][['PLAYER NAME','SIXERS']]
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 28  Gilchrist, AC      86
# 82     Pathan, YK      81
# 88      Raina, SK      97
# 97     Sharma, RG      82

# %% [markdown]
# ## DROPPING COLUMNS

# %%
X = df.drop('Sl.NO.',axis=1)

# %%
X
# Out:
#       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0     Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1    Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2     Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3       Ashwin, R    1     IND    CSK       Bowler     284      31
# 4    Badrinath, S    2     IND    CSK      Batsman      63       0
# ..            ...  ...     ...    ...          ...     ...     ...
# 125     Yadav, AS    2     IND     DC      Batsman       0       0
# 126   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00         0  ...       0     307    15   20.47   8.90
# ...

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.drop('Sl.NO.',axis = 1, inplace = True)

# %%
df
# Out:
#       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0     Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1    Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2     Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3       Ashwin, R    1     IND    CSK       Bowler     284      31
# 4    Badrinath, S    2     IND    CSK      Batsman      63       0
# ..            ...  ...     ...    ...          ...     ...     ...
# 125     Yadav, AS    2     IND     DC      Batsman       0       0
# 126   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00         0  ...       0     307    15   20.47   8.90
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe().T
# Out:
#                count           mean            std      min          25%  \
# AGE            130.0       2.092308       0.576627      1.0       2.0000
# T-RUNS         130.0    2166.715385    3305.646757      0.0      25.5000
# T-WKTS         130.0      66.530769     142.676855      0.0       0.0000
# ODI-RUNS-S     130.0    2508.738462    3582.205625      0.0      73.2500
# ODI-SR-B       130.0      71.164385      25.898440      0.0      65.6500
# ODI-WKTS       130.0      76.076923     111.205070      0.0       0.0000
# ODI-SR-BL      130.0      34.033846      26.751749      0.0       0.0000
# CAPTAINCY EXP  130.0       0.315385       0.466466      0.0       0.0000
# RUNS-S         130.0     514.246154     615.226335      0.0      39.0000
# HS             130.0      47.430769      36.403624      0.0      16.0000
# AVE            130.0      18.719308      11.094224      0.0       9.8250
# SR-B           130.0     111.053462      35.928907      0.0      98.2375
# ...

# %%
df.groupby('AGE')['SOLD PRICE'].std()
# Out:
# AGE
# 1    493667.566958
# 2    394308.499638
# 3    371561.973653
# Name: SOLD PRICE, dtype: float64

# %% [markdown]
# ## IQR

# %%
df['SOLD PRICE'].quantile(.75)-df['SOLD PRICE'].quantile(.25)
# Out:
# 475000.0

# %%
df.describe(include = ['O']).T
# Out:
#              count unique          top freq
# PLAYER NAME    130    130  Abdulla, YA    1
# COUNTRY        130     10          IND   53
# TEAM           130     17          CSK   14
# PLAYING ROLE   130      4       Bowler   44

# %%
df.describe(include = 'all').T
# Out:
#                count unique          top freq           mean            std  \
# PLAYER NAME      130    130  Abdulla, YA    1            NaN            NaN
# AGE            130.0    NaN          NaN  NaN       2.092308       0.576627
# COUNTRY          130     10          IND   53            NaN            NaN
# TEAM             130     17          CSK   14            NaN            NaN
# PLAYING ROLE     130      4       Bowler   44            NaN            NaN
# T-RUNS         130.0    NaN          NaN  NaN    2166.715385    3305.646757
# T-WKTS         130.0    NaN          NaN  NaN      66.530769     142.676855
# ODI-RUNS-S     130.0    NaN          NaN  NaN    2508.738462    3582.205625
# ODI-SR-B       130.0    NaN          NaN  NaN      71.164385       25.89844
# ODI-WKTS       130.0    NaN          NaN  NaN      76.076923      111.20507
# ODI-SR-BL      130.0    NaN          NaN  NaN      34.033846      26.751749
# ...

# %% [markdown]
# ## Visualiztion

# %%
sns.barplot(x =df['AGE'],y=df['SOLD PRICE'],ci =None)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sns.barplot(x =df['AGE'],y=df['SOLD PRICE'],hue = df['PLAYING ROLE'],ci =None)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sns.histplot(df['SOLD PRICE'], kde = True)
# Out:
# <AxesSubplot:xlabel='SOLD PRICE', ylabel='Count'>

# %%
sns.boxplot(df['SOLD PRICE'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SOLD PRICE'>

# %% [markdown]
# ## Assignment -- create function to detect outliers and remove outliers-----z score and iqr method

# %%
box = plt.boxplot(df['SOLD PRICE'])

# %%
[item.get_ydata()[0] for item in box['caps']] ## upper limit and lower limit directly.
# Out:
# [20000, 1350000]

# %% [markdown]
# Lower cap = 20000 and Upper Cap = 1350000

# %%
[item.get_ydata()[0] for item in box['whiskers']]
# Out:
# [225000.0, 700000.0]

# %% [markdown]
# scatter plot

# %%
sns.scatterplot(x = df['SIXERS'], y = df['SOLD PRICE'])
# Out:
# <AxesSubplot:xlabel='SIXERS', ylabel='SOLD PRICE'>

# %%
sns.lmplot(x = 'SIXERS', y = 'SOLD PRICE', data = df)

# %%
## Pairplot
columns = ['SR-B','AVE','SIXERS','SOLD PRICE']

# %%
df.columns
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE', 'PREMIUM'],
#       dtype='object')

# %%
sns.pairplot(df[columns], kind = 'reg')

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df[columns].corr(), annot = True)
# Out:
# <AxesSubplot:>
